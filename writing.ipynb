# %%
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt
import tensorflow as tf

mnlist = tf.keras.datasets.mnist
(x_train, y_train), (x_test, y_test) = mnlist.load_data()

x_train = tf.keras.utils.normalize(x_train, axis=1)
x_test = tf.keras.utils.normalize(x_test, axis=1)
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Flatten(input_shape=(28, 28)))
model.add(tf.keras.layers.Dense(units=128, activation=tf.nn.relu))
model.add(tf.keras.layers.Dense(units=128, activation=tf.nn.relu))
model.add(tf.keras.layers.Dense(units=10, activation=tf.nn.softmax))

model.compile(optimizer="adam", loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.fit(x_train, y_train, epochs=3)
accuracy, loss = model.evaluate(x_test, y_test)
print(accuracy)
print(loss)

model.save('digits.model')
x
# Out:
# Epoch 1/3
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2667 - accuracy: 0.9205
# Epoch 2/3
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1082 - accuracy: 0.9663
# Epoch 3/3
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0725 - accuracy: 0.9774
# 313/313 [==============================] - 1s 1ms/step - loss: 0.0985 - accuracy: 0.9687
# 0.09848640859127045
# 0.9686999917030334
# INFO:tensorflow:Assets written to: digits.model/assets
